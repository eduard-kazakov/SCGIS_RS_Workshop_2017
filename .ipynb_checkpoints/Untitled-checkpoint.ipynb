# %%
from osgeo import gdal
import matplotlib.pyplot as plt
from IPython.display import Image
import matplotlib as mpl
import numpy as np
mpl.rcParams['figure.figsize'] = (10,10)

# %%
a = gdal.Open('/home/silent/Downloads/LM21990181981250AAA03/LM21990181981250AAA03_B4.TIF')
b = gdal.Open('/home/silent/Downloads/LM21990181981250AAA03/LM21990181981250AAA03_B5.TIF')
data = a.GetRasterBand(1).ReadAsArray()
data2 = b.GetRasterBand(1).ReadAsArray()
#data [data==0] = np.nan
#plt.imshow(data[mask])
plt.imshow(data[1500:2000,1500:2000],vmin=0,vmax=200,cmap='rainbow')
plt.figure(figsize=(10,15))
plt.show()

# %%
n, bins, patches = plt.hist(data.ravel(), 50, normed=1, range=(1,np.nanmax(data)), facecolor='green', alpha=0.75)
plt.show()

# %%
plt.plot(data[1500:2000,1500:2000].ravel(),data2[1500:2000,1500:2000].ravel(),'o')
plt.show()
